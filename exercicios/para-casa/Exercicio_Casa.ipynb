# %% [markdown]
# # Exercicio para casa
#
# Desafio: Criar um dashboard com os dados da Olist a partir da sua base final criada na Semana 14.
#
# Requisitos:
# - Formular o mínimo de 6 visualizações diferentes;
# - Utilizar a sua base final criada com os dados da Olist (caso você deseje enriquecer sua base conforme você for criando as visualizações, fique à vontade!);
# - Publicar seu dashboard final no repositório do Tableau.

# %%
# Base dados utilizada, foi a minha Base_final_2_Olist aula semana-14
import pandas as pd

df = pd.read_csv('../para-casa/Base_final_2_olist.csv')
df.head()
# Out:
#                            order_id payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953  credit_card
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  0a8556ac6be836b46b3e89920d59291c    delivered      2018-04-25 22:01:49
# 1  f2c7fc58a9de810828715166c672f10a    delivered      2018-06-26 11:01:38
# 2  25b14b69de0b6e184ae6fe2755e478f9    delivered      2017-12-12 11:19:55
# 3  7a5d8efaaa1081f800628c30d2b0728f    delivered      2017-12-06 12:04:06
# 4  7a5d8efaaa1081f800628c30d2b0728f    delivered      2017-12-06 12:04:06
#
#   order_delivered_customer_date reference_month_year  order_item_id  \
# 0           2018-05-09 17:36:51           2018-04-01              1
# 1           2018-06-29 20:32:09           2018-06-01              1
# ...

# %% [markdown]
# # 1º Visualização (Avaliações dos clientes)
#
# Fiz a média das avaliações dos clientes por mês, utilizando a coluna "review_score" e também a "reference_month_year" para filtar somente os meses.
# Utilizei a tabela com  as colunas e as cores para diferenciar as avaliações.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2º Visualização (Top 10 Categorias)
#
# Nessa visualização filtrei as 10 categorias mais vendidas e a quantidade que foi vendido, usando as colunas "product_category_name" para filtrar os produtos mais vendidos e a "Price" para somar o total de cada categoria.
# E ambas as colunas também foram utilizadas no rótulo para poder ter a visualização no gráfico.
# Utilizei o gráfico de barras
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 3º Visualização (Status Pedido)
#
# Nessa visualização filtrei apenas os pedidos entregues(finalizados) e os cancelados usando a coluna "order_status" e também a coluna "reference_month_year" para referenciar os meses, usei a função Cont([order_status]) no rótulo para fazer a contagem dos valores da coluna e mostrar no gráfico os totais e a "order_status" na cor para diferenciar as linhas.
# Utilizei o gráfico de linhas.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 4º Visualização (Total de Vendas por Estados)
#
# Nessa visualização usei apenas duas colunas "price" para somar o total das vendas e a coluna "customer_state" para referenciar os estados.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 5º Visualização (Ticket médio por Estado)
#
# Nessa visualização utilizei a colunas geografica "Customer State", tive que criar dois campos calculados "Country" e "Regiões", pois não tinham essas informações no meu banco de dados.
# Depois tive quer criar a hierarquia com todos os campos geograficos para poder assim montar o mapa geográfico com as informações.
# Nos rótulos usei os estados e o valor do ticket médio para visualizar no gráfico  e na cor usei as regiões para diferenciar por regiões do Brasil.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 6º Visualização (Resumo para o Mapa)
#
# Nessa visualização fiz um resumo para montar a dashboard do mapa.
# Com as informações
# * quantidade de cliente
# * quantidade de pedidos
# * quantidade vendido(produtos)
# * total de vendas
# * ticket médio
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 1º Dashboard
#
# Avaliação de desempenho das vendas e comportamento dos clientes.
# Nessa dash podemos avaliar sobre a quantidade de pedidos cancelados em relação aos pedidos finalizados.
# Avaliar a média de satisfação dos clientes pelas availiações e as preferências ou o publico pelo o top 10 categorias mais vendidas.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2º Dashboard (Total de Vendas por Estados)
#
# Nessa dashboard podemos avaliar o total das vendas por estado, vendo qual vendeu mais e qual vendeu menos.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3º Dashboard (Ticket Médio de vendas por estado)
#
# Nessa dashboard podemos avaliar em qual região tem o ticket médio mais alto.
#
# ![image.png](attachment:image.png)

# %% [markdown]
#  # link Analise descritiva Olist
#
# https://public.tableau.com/views/AnaliseDescritivaOlist/TicketMdioVendasporEstado?:language=pt-BR&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link
