# %% [markdown]
# ### Minha análise foi direciada aos pedidos e vendas feitas para a região nordeste. O link para visualizar a realização do exercício: https://public.tableau.com/views/Exer_Aula_S15/Dash_Top10_Vendas_NE?:language=pt-BR&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link
#
# ### Primeiro eu vi as vendas e pedidos de modo geral:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Depois, a análise foi feita com as top 10 cidades que geram mais vendas:
#
# ![](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
