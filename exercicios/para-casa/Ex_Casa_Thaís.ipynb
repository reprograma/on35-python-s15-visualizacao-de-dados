# %% [markdown]
# # Exercício Casa - S15

# %% [markdown]
# #### Link Tableau:
# https://public.tableau.com/shared/R7Y95DQXH?:display_count=n&:origin=viz_share_link

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
