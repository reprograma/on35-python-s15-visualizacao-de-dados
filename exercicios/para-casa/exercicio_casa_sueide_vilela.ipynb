# %% [markdown]
# # Exercício de Casa 🏠

# %% [markdown]
# ### Desafio: Criar um dashboard com os dados da Olist a partir da sua base final criada na Semana 14.

# %% [markdown]
# ![{EE64C84A-3788-4161-BA12-E62C83649082}.png](attachment:{EE64C84A-3788-4161-BA12-E62C83649082}.png)

# %% [markdown]
# ![{93CA9A69-053C-432C-8C93-F2E3976A6C2C}.png](attachment:{93CA9A69-053C-432C-8C93-F2E3976A6C2C}.png)

# %% [markdown]
# ![{3A92B447-56F5-42AE-AF55-B0C7080F6694}.png](attachment:{3A92B447-56F5-42AE-AF55-B0C7080F6694}.png)

# %% [markdown]
# ![{35C56990-DC29-4DD1-96AF-E048CAAF7D31}.png](attachment:{35C56990-DC29-4DD1-96AF-E048CAAF7D31}.png)

# %% [markdown]
# ### Formular o mínimo de 6 visualizações diferentes.

# %% [markdown]
# ![Valores de receita e desempenho de vendas.png](<attachment:Valores de receita e desempenho de vendas.png>)

# %% [markdown]
# ![Preços ao longo do tempo.png](<attachment:Preços ao longo do tempo.png>)

# %% [markdown]
# ![Valores de pagamentos.png](<attachment:Valores de pagamentos.png>)

# %% [markdown]
# ![Valores de frete.png](<attachment:Valores de frete.png>)

# %% [markdown]
# ![Parcelamentos e tipos de pagamentos.png](<attachment:Parcelamentos e tipos de pagamentos.png>)

# %% [markdown]
# ![Tipos de pagamentos.png](<attachment:Tipos de pagamentos.png>)

# %% [markdown]
# ### Utilizar a sua base final criada com os dados da Olist.
#
# O arquivo da minha base final criada com os dados da Olist está na pasta de "para-casa", o nome do CSV utilizado para as análises é: "base_final_exercicio_casa_s14_olist"

# %% [markdown]
# ### Publicar seu dashboard final no repositório do Tableau.
#
# O meu dashboard final publicado no Tableu pode ser acessado pelo link a seguir:
#
# https://public.tableau.com/app/profile/sueide.vilela/viz/Desafiodasemana15/Painel1
