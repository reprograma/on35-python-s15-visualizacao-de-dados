# %% [markdown]
# Link Tableau: https://public.tableau.com/authoring/ExercicioAula15/StatusdeEntrega/Dash%20Status-Vendas-Varia%C3%A7%C3%A3o#1

# %% [markdown]
# Valor de Venda por Estado
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Valor de Venda Mês e Ano SC
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Dash Estado e Ano
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Top 10 Vendas SC
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Variação de Vendas SC
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Status de Entrega
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Dash Status-Vendas-Variação
#
# ![image.png](attachment:image.png)
