# %% [markdown]
# Link Tableau : https://public.tableau.com/views/Exercicioaula15Reprograma/VendaporEstado?:language=pt-BR&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link

# %% [markdown]
# Valor de venda por estado
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Valor Venda mês/ano Bahia
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Dash estado/ano
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Top 10 de venda
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Variação de venda
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Status de entrega
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Dash Final
#
# ![image.png](attachment:image.png)
