# %% [markdown]
# **Para acessar o link da minha atividade proposta na aula:
#
# https://public.tableau.com/views/Atividade-para-sala/Painel2?:language=pt-BR&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link

# %% [markdown]
# **Print da Atividade - Dashboard**
#
# ![image.png](attachment:image.png)
